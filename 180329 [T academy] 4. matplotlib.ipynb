# %% [markdown]
# # matplotlib

# %% [markdown]
# pip install matplotlib

# %% [markdown]
# https://matplotlib.org/gallery/index.html

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# **Functional Method**

# %%
plt.plot(x, y)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Title')
# Out:
# Text(0.5,1,'Title')

# %% [markdown]
# Create Multi-plots

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %% [markdown]
# **Object-oriented Method**

# %%
# create figure object (empty canvas)
fig = plt.figure()

# define the location of the axes
# [ left, bottom, width, height ]

axes = fig.add_axes([ 0.1, 0.1, 0.8, 0.8 ])

axes.plot(x,y)
axes.set_xlabel( 'X Label' )
axes.set_ylabel( 'Y Label' )
axes.set_title( 'Set Title' )
# Out:
# Text(0.5,1,'Set Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x,y)
axes1.set_title('LARGER PLOT')
axes2.plot(y,x)
axes2.set_title('SMALLER PLOT')
# Out:
# Text(0.5,1,'SMALLER PLOT')

# %% [markdown]
# Create Subplots

# %%
fig, axes = plt.subplots( nrows = 1, ncols = 2 )

axes[0].plot(x,y)
axes[0].set_title('First Plot')

axes[1].plot(y,x)
axes[1].set_title('Second Plot')

plt.tight_layout()

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0DF3B4F0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0EF8D610>],
#       dtype=object)

# %% [markdown]
# Figure Size and DPI

# %%
fig = plt.figure(figsize = (8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows = 2, ncols = 1, figsize = (8,2))

axes[0].plot(x,y)
axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# Save a Figure

# %%
fig.savefig( 'my_picture.png', dpi = 200 )

# %% [markdown]
# Adding a Legend

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot( x, x ** 2, label = 'X Squared' )
ax.plot( x, x ** 3, label = 'X Cubed' )

ax.legend( loc = (0.1, 0.1) )
# 0 ~ 10 locations

# %% [markdown]
# Plot Appearance

# %%
fig = plt.figure()
ax = fig.add_axes( [0, 0, 1, 1] )

ax.plot( x, y, color = '#FF8C00', linewidth = 0.5, alpha = 0.5,
       linestyle = '--', marker = 'o', markersize = 20,
       markerfacecolor = 'yellow', markeredgewidth = 3, 
        markeredgecolor = 'green') 
# refer to the 'RGB Hex Code' for custom colors
# marker = o, +, *, 1, 2, etc.

# %%
fig = plt.figure()
ax = fig.add_axes( [0, 0, 1, 1] )

ax.plot( x, y, color = 'purple', lw = 2, ls = '--' )

ax.set_xlim( [0, 1] )
ax.set_ylim( [0, 2] )
# Out:
# (0, 2)

# %% [markdown]
# matplotlib Tutorial
#
# http://www.loria.fr/~rougier/teaching/matplotlib

# %% [markdown]
# Plotting a Figure
# 1. Call figure
# 2. Add axes to the figure
# 3. Plot on the axes
#
# Subplots
# 1. fig,axes = plt.subplots()
# 2. Iterate through the axes (by calling the array of axes)
